# %%
#Code to upload the file

from google.colab import files
uploaded = files.upload()

import pandas as pd

df = pd.read_excel("Walmart.xlsx")
df.head()
# Out:
#      <input type="file" id="files-308b98c4-0b58-453f-85f4-981d68ff8f28" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-308b98c4-0b58-453f-85f4-981d68ff8f28">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 402.3 KB
#              Store                 Date  Weekly_Sales  Holiday_Flag  \
# count  6435.000000                 6435  6.435000e+03   6435.000000
# mean     23.000000  2011-06-17 00:00:00  1.046965e+06      0.069930
# min       1.000000  2010-02-05 00:00:00  2.099862e+05      0.000000
# 25%      12.000000  2010-10-08 00:00:00  5.533501e+05      0.000000
# ...

# %%
#Converting the date column

df['Date'] = pd.to_datetime(df['Date'])

# %%
#Checking the missing values

df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
# Total sales per store

df.groupby('Store')['Weekly_Sales'].sum().sort_values(ascending=True)
# Out:
# Store
# 33    3.716022e+07
# 44    4.329309e+07
# 5     4.547569e+07
# 36    5.341221e+07
# 38    5.515963e+07
# 3     5.758674e+07
# 30    6.271689e+07
# 37    7.420274e+07
# 16    7.425243e+07
# 29    7.714155e+07
# 9     7.778922e+07
# 42    7.956575e+07
# 7     8.159828e+07
# 15    8.913368e+07
# 43    9.056544e+07
# 25    1.010612e+08
# 21    1.081179e+08
# 45    1.123953e+08
# 17    1.277821e+08
# 8     1.299512e+08
# 35    1.315207e+08
# 40    1.378703e+08
# 34    1.382498e+08
# 26    1.434164e+08
# 12    1.442872e+08
# 22    1.470756e+08
# 18    1.551147e+08
# 32    1.668192e+08
# 41    1.813419e+08
# 28    1.892637e+08
# 11    1.939628e+08
# 24    1.940160e+08
# 23    1.987506e+08
# 31    1.996139e+08
# 19    2.066349e+08
# 39    2.074455e+08
# 1     2.224028e+08
# 6     2.237561e+08
# 27    2.538559e+08
# 10    2.716177e+08
# 2     2.753824e+08
# 13    2.865177e+08
# 14    2.889999e+08
# 4     2.995440e+08
# 20    3.013978e+08
# Name: Weekly_Sales, dtype: float64

# %%
#Holidays vs Non Holidays

df.groupby('Holiday_Flag')['Weekly_Sales'].mean()
# Out:
# Holiday_Flag
# 0    1.041256e+06
# 1    1.122888e+06
# Name: Weekly_Sales, dtype: float64

# %%
#Corelation

df.corr()
# Out:
#                      Store          Date  Weekly_Sales  Holiday_Flag  \
# Store         1.000000e+00  1.577299e-13     -0.335332 -4.386841e-16
# Date          1.577299e-13  1.000000e+00      0.006949 -1.328524e-02
# Weekly_Sales -3.353320e-01  6.949360e-03      1.000000  3.689097e-02
# Holiday_Flag -4.386841e-16 -1.328524e-02      0.036891  1.000000e+00
# Temperature  -2.265908e-02  1.453566e-01     -0.063810 -1.550913e-01
# Fuel_Price    6.002295e-02  7.714439e-01      0.009464 -7.834652e-02
# CPI          -2.094919e-01  7.715746e-02     -0.072634 -2.162091e-03
# Unemployment  2.235313e-01 -2.482029e-01     -0.106176  1.096028e-02
#
#               Temperature  Fuel_Price       CPI  Unemployment
# Store           -0.022659    0.060023 -0.209492      0.223531
# Date             0.145357    0.771444  0.077157     -0.248203
# Weekly_Sales    -0.063810    0.009464 -0.072634     -0.106176
# Holiday_Flag    -0.155091   -0.078347 -0.002162      0.010960
# ...

# %%
#Averaging sales per month

import pandas as pd
import matplotlib.pyplot as plt

df['Date'] = pd.to_datetime(df['Date'])
weekly_sales = df.groupby('Date')['Weekly_Sales'].mean()  # mean or sum

plt.figure(figsize=(12,6))
plt.plot(weekly_sales, color='blue')
plt.title('Average Weekly Sales Over Time')
plt.ylabel('Weekly Sales')
plt.xlabel('Date')
plt.show()

# %%
#Showing analysis by a heatmap

import seaborn as sns

plt.figure()
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
#Feature engineering

df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# %%
#Linear Regression

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = df[['Temperature', 'Fuel_Price', 'CPI', 'Unemployment']]
y = df['Weekly_Sales']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LinearRegression()
model.fit(X_train, y_train)

model.score(X_test, y_test)
# Out:
# 0.03174654430506885

# %% [markdown]
# By running the linear regression code, we see only 3.17 % of the change is explained in the weekly sales by the independent variable factors I have provided which means they are not a very strong indicator of the weekly sales.
